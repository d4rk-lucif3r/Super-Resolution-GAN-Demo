# %% [markdown]
# ## Importing Libraries

# %%
import cv2
import plotly.express as px
from super_res_gan import main

# %% [markdown]
# ## Test Image

# %%
test_image = '/Users/arshanwar/Arsh/FL/TF/superres/SRGAN/samples/pika.jpeg'
test_image_read = cv2.imread(test_image)
test_image_read = cv2.cvtColor(test_image_read, cv2.COLOR_BGR2RGB)

# %%
px.imshow(test_image_read, template='plotly_dark')

# %% [markdown]
# ## Super Resolved Image

# %%
res = main(test_image)

# %%
px.imshow(res, template='plotly_dark')

# %% [markdown]
# ## Deployment on TrueFoundry

# %%
from servicefoundry import Build, DockerBuild, Resources, Service
import os

os.environ["TFY_HOST"] = "https://app.truefoundry.com/"
os.environ["TFY_API_KEY"] = "<your-api-key>"  # replace this


service = Service(
    name="image-colorizer",
    image=Build(
        build_spec=DockerBuild(),
    ),
    ports=[{"port": 8080}],
    resources=Resources(memory_limit=1000, memory_request=500,
                        cpu_limit=2, cpu_request=1.5),
)
service.deploy(workspace_fqn="<your-workspace-fqn>")
